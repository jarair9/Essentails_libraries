# %% [markdown]
# # Pandas
#
# Pandas word come from panel data , Mean data. Pandas is Used in most of top Computer science fields like Data science , Machine learning, AI engineering and etc. It is used for data cleaning , organizing, Data information , Data summary , also used for getting key insights from data and manipulation.

# %%
import pandas as pd

data = pd.read_csv("Employee Sample Data 1.csv",encoding="latin-1")

# data.head()

data["Department"] = "IT"
data["Age"] < 30
data.head()
